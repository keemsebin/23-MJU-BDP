# %%
import os
from selenium import webdriver
from bs4 import BeautifulSoup
from selenium.webdriver.chrome.service import Service
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
import time 
import pyperclip
import pyautogui
import random

user_agent = "user-agent header"
options = Options()
options.add_argument('user-agent=' + user_agent)
options.add_argument('--mute-audio')
options.add_experimental_option("detach", True)
options.add_experimental_option("excludeSwitches", ["enable-logging"])
driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
driver.implicitly_wait(5)

uid = 'naverid'
upw = 'naverpassword'

url = ('https://nid.naver.com/nidlogin.login?mode=form&url=https%3A%2F%2Fwww.naver.com')

driver.get(url) 

tag_id = driver.find_element(By.CSS_SELECTOR,'#id') 
tag_id.click() 
pyperclip.copy(uid) 
pyautogui.keyDown ('ctrl') 
pyautogui.press ('v') 
pyautogui.keyUp ('ctrl')
time.sleep(2)

tag_pw = driver.find_element(By.CSS_SELECTOR,'#pw') 
tag_pw.click() 
pyperclip.copy(upw) 
pyautogui.keyDown ('ctrl') 
pyautogui.press ('v') 
pyautogui.keyUp ('ctrl')
time.sleep(2) 

login_btn = driver.find_element(By.ID,'log.login') 
login_btn.click() 
time.sleep(2)

def move_page(page):
    key_url = 'https://cafe.naver.com/ArticleList.nhn?search.clubid=15424483&search.menuid=692&search.boardtype=L&search.page={}'.format(page)
    return key_url

data = [] 

for i in range( 1, 1000 ):
    url = move_page(i)
    driver.get(url)
    driver.switch_to.frame('cafe_main')
    search_url = driver.page_source
    soup = BeautifulSoup(search_url, 'html.parser')
    articles = soup.select('tr')
    
    for article in articles:
        if article.get('class', []) is not None and '_noticeArticle' in article.get('class', []):  # 공지사항은 크롤링에서 제외
            continue 
        subject = article.find('a', class_='article')  # 제목 선택
        date = article.find('td', class_='td_date')  # 날짜 선택

        if subject is None or date is None:
            continue

        if '해외핫딜 매장 왔어요 인기상품 국내패션핫딜 브랜드 후기 발표 국내패션핫딜 직구팁' not in subject.text:   
        # '해외핫딜'이 포함되지 않은 글만 선택
            span = subject.find('span')
            if span is not None:  # <span> 태그가 있는 경우
                title = subject.text.replace(span.text, '').strip()  # <span> 태그의 텍스트를 제거
            else:  # <span> 태그가 없는 경우
                title = subject.text.strip()
        print(title,',', date.text.strip())
        data.append(title + ' , ' + date.text.strip())
    time.sleep(random.uniform(2,4))

c = os.path.exists('crawling.txt')    
if c:
    os.remove('crawling.txt')
        
with open('crawling.txt', 'w', encoding='utf-8') as f:
    for line in data:
        for l in line:
            f.write(l)
        f.write('\n')
# Out:
# 인생슬랙스를 찾아 겨울용 슬랙스를 종류별로 사봤습니다🤔 , 2023.11.27.
# 메종키츠네 가디건 , 2023.11.26.
# 방수스프레이🫧 , 2023.11.26.
# 톰보이 무스탕 😆 , 2023.11.29.
# ssf 메종키츠네 가디건 따사했어요 🤍 , 2023.11.26.
# 무신사 파산핑 슈가베리팩트 🩷 , 02:15
# 어샀) ㅁㅅㅅ 캘빈클라인 진 다운 푸퍼 샀어요 , 01:21
# 버버리 케이프 , 어그 코케트샀어요. , 00:30
# ㄹㄷㅁㅅㅈ 알콜삿서여 🥃💗 , 00:18
# 보테가베네타 카세트백 드뎌 샀어요😅 , 00:14
# 시마을 크리니크 수분크림, 스틸라 아이팔래트 샀어요 , 2023.11.30.
# 면세점 온라인 구매했어요 감사합니다..🫣💕 , 2023.11.30.
# 유니클로 겟겟 , 2023.11.30.
# 하트귀걸이 샀어용🫶🏻 , 2023.11.30.
# 무신사 어센틱 , 2023.11.30.
# 뉴진스 해린 백팩 샀어용 , 2023.11.30.
# 뉴발란스 운동화 샀어요~ , 2023.11.30.
# 어그 클리어 미니부츠 샀어요🖤 , 2023.11.30.
# 잔스포츠코듀로이따라샀어요 , 2023.11.30.
# ㅁㅅㅅ 제네럴아이디어 가디건 샀어요 , 2023.11.30.
# 디올뷰티 - 튀튀 블러쉬, 뷰러 샀어요 , 2023.11.30.
# 어샀)ㅁㅅㅅ 모자샀어요 , 2023.11.30.
# (예샀) ㄱㄷ 버버리 머플러 샀어요 , 2023.11.30.
# (예샀)ㅈㅁㅋ에서 비비안웨스트우드 버킷햇 샀어요 , 2023.11.30.
# ㅁㅅㅅ어그클리어블랙샀어용 , 2023.11.30.
# 천사님께 로떼ㅁㅅㅈ 쿠폰 나눔받아서 샀어요! , 2023.11.30.
# Archivepke 부츠 샀어요 , 2023.11.30.
# 운동은 장비빨😂 젝시믹스 샀어요 , 2023.11.30.
# ㅁㅅㅅ 골든구스 슈퍼스타 베이지 나이트블루탭 샀어요 , 2023.11.30.
# 빈폴, 메종키츠네 양말 샀어요 , 2023.11.30.
# ㅁㅅㅅ 반스 어센틱 레더 샀어유..🖤 , 2023.11.30.
# 헤라 센슈얼 립밤 샀어용 , 2023.11.30.
# 쥔님 장난감 사줬어여🐶🤍🤍 , 2023.11.30.
# 크림 첫구매 후덜덜 , 2023.11.30.
# 샤넬 립, cc참 샀어요😗😗 , 2023.11.30.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 57
#      55 for i in range( 1, 1000 ):
#      56     url = move_page(i)
# ---> 57     driver.get(url)
#      58     driver.switch_to.frame('cafe_main')
#      59     search_url = driver.page_source
#
# File /opt/homebrew/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py:356, in WebDriver.get(self, url)
#     354 def get(self, url: str) -> None:
#     355     """Loads a web page in the current browser session."""
# --> 356     self.execute(Command.GET, {"url": url})
#
# File /opt/homebrew/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py:345, in WebDriver.execute(self, driver_command, params)
#     342     elif "sessionId" not in params:
#     343         params["sessionId"] = self.session_id
# --> 345 response = self.command_executor.execute(driver_command, params)
#     346 if response:
#     347     self.error_handler.check_response(response)
#
# File /opt/homebrew/lib/python3.11/site-packages/selenium/webdriver/remote/remote_connection.py:300, in RemoteConnection.execute(self, command, params)
#     298 data = utils.dump_json(params)
#     299 url = f"{self._url}{path}"
# --> 300 return self._request(command_info[0], url, body=data)
#
# File /opt/homebrew/lib/python3.11/site-packages/selenium/webdriver/remote/remote_connection.py:321, in RemoteConnection._request(self, method, url, body)
#     318     body = None
#     320 if self.keep_alive:
# --> 321     response = self._conn.request(method, url, body=body, headers=headers)
#     322     statuscode = response.status
#     323 else:
#
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/_request_methods.py:118, in RequestMethods.request(self, method, url, body, fields, headers, json, **urlopen_kw)
#     110     return self.request_encode_url(
#     111         method,
#     112         url,
#    (...)
#     115         **urlopen_kw,
#     116     )
#     117 else:
# --> 118     return self.request_encode_body(
#     119         method, url, fields=fields, headers=headers, **urlopen_kw
#     120     )
#
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/_request_methods.py:217, in RequestMethods.request_encode_body(self, method, url, fields, headers, encode_multipart, multipart_boundary, **urlopen_kw)
#     213     extra_kw["headers"].setdefault("Content-Type", content_type)
#     215 extra_kw.update(urlopen_kw)
# --> 217 return self.urlopen(method, url, **extra_kw)
#
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/poolmanager.py:443, in PoolManager.urlopen(self, method, url, redirect, **kw)
#     441     response = conn.urlopen(method, url, **kw)
#     442 else:
# --> 443     response = conn.urlopen(method, u.request_uri, **kw)
#     445 redirect_location = redirect and response.get_redirect_location()
#     446 if not redirect_location:
#
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/connectionpool.py:790, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     787 response_conn = conn if not release_conn else None
#     789 # Make the request on the HTTPConnection object
# --> 790 response = self._make_request(
#     791     conn,
#     792     method,
#     793     url,
#     794     timeout=timeout_obj,
#     795     body=body,
#     796     headers=headers,
#     797     chunked=chunked,
#     798     retries=retries,
#     799     response_conn=response_conn,
#     800     preload_content=preload_content,
#     801     decode_content=decode_content,
#     802     **response_kw,
#     803 )
#     805 # Everything went great!
#     806 clean_exit = True
#
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File /opt/homebrew/lib/python3.11/site-packages/urllib3/connection.py:461, in HTTPConnection.getresponse(self)
#     458 from .response import HTTPResponse
#     460 # Get the response from http.client.HTTPConnection
# --> 461 httplib_response = super().getresponse()
#     463 try:
#     464     assert_header_parsing(httplib_response.msg)
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:1378, in HTTPConnection.getresponse(self)
#    1376 try:
#    1377     try:
# -> 1378         response.begin()
#    1379     except ConnectionError:
#    1380         self.close()
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/http/client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File /opt/homebrew/Cellar/python@3.11/3.11.5/Frameworks/Python.framework/Versions/3.11/lib/python3.11/socket.py:706, in SocketIO.readinto(self, b)
#     704 while True:
#     705     try:
# --> 706         return self._sock.recv_into(b)
#     707     except timeout:
#     708         self._timeout_occurred = True
#
# KeyboardInterrupt:
